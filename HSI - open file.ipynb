# %%
from astropy.io import fits
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
filename = '/Users/last/PycharmProjects/other/HSI/start/1.fits'
hdul = fits.open(filename)
print(hdul.info())
print(hdul[0].header)
# Out:
# Filename: /Users/last/PycharmProjects/other/HSI/start/1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   (2048, 1088)   uint8
# None
# ...

# %%
data = hdul[0].data
print(data.shape)
plt.matshow(data, cmap='gray')
# Out:
# (1088, 2048)

# %%
sub = data[500:900, :]
plt.matshow(sub, cmap='gray')

# %%
shiftX = 2
shiftY = 2
posX = 0
posY = 0
resX = (data.shape[1]-shiftX)//5
resY = (data.shape[0]-shiftY)//5
print(resX, resY)
d0 = np.zeros((resY, resX), dtype=np.int16)
d0.shape
cube = np.zeros((resY, resX, 25), dtype=np.int8)
for col in range(25):
    posX = col % 5
    posY = col // 5
    for i in range(resY):
        for j in range(resX):
            cube[i, j, col] = data[5*i + shiftY + posY, 5*j + shiftX + posX]
plt.matshow(cube[:, :, 17], cmap='gray')
# Out:
# 409 217
